# %% [markdown]
# # GREEN AI Projetct - DIA6
# # Energy Optimization in New York's Buildings Using Artificial Intelligence
# Gabriel SULTAN,
# Yasmine ZEROUAL,
# Lalith Adithya CHANUMOLU

# %% [markdown]
# Buildings in big cities like New York use a lot of energy every day for heating, cooling, electricity, and hot water. This high energy use creates large CO₂ emissions and high costs. To reduce this impact, it is important to understand how buildings consume energy and how we can improve their efficiency.
#
# Machine Learning can help by learning patterns from past energy readings. By combining weather data, building characteristics, and meter values, ML models can predict future consumption and identify unusual behavior in buildings.

# %% [markdown]
# # Articles used :

# %% [markdown]
# Article 1 : Optimizing building energy performance predictions: A comparative study of artificial intelligence models
#
# https://pdf.sciencedirectassets.com/312002/1-s2.0-S2352710224X00054/1-s2.0-S2352710224008155/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEHQaCXVzLWVhc3QtMSJGMEQCIF%2BrFxv9xTl6lldj6CzeQHnArqwc%2BzD5Wx2B%2Fjnyo%2BuqAiBDZ8c6vNpkk12aIUVDphVVfW0HfLCxBNDzZPGSJSoGziqyBQgtEAUaDDA1OTAwMzU0Njg2NSIMhhj0ORyOFYVr9OooKo8FIU8l7YwRWuU%2BZWnXPLBHc21fP9%2F%2FKhwt%2BetFIMEygq%2F8HWDme67WifKR3qrPXFBmWgiSPKkD1X4nONeFW%2BqvEr%2FyPE0TneiYJAgvuxGUDUWcLgaIyEn6z%2FnvLKRIAH44NTPwZAOHx%2FlWBQLmLy%2FvxJlUtPmfadZmdj9CEhR1tn%2Fyesrci9fsL38JK80YnYaAIJuoUtY3n5G80YWTb80FTEu5Q0jDJOltFnChXvZps1Vp7w5LiOm0dS2zmv7f9yuqpqonXZvgKFlmR3Bx74D%2Bkq%2FN30HT%2BTmhd1d7gtWDcYyrCzGER%2FX%2FhcfeCd%2BXv2XNnkfVTC%2FDl5%2Bigu7GJWTl24%2BvT%2Bzpgb1EvSoMEc%2FDShoLUzb7dsDl60GIr5P57%2FFGY10VhrIP%2FoxcOiUORX5ZHEPIB8iy04EHPgjJduFmcrjkXXUxkK7GS7FqZCqd4oQzMvDV4UbS%2FTcEMT%2Fjaag8YhypGRx5VYHFsViGoA10KUqn4%2FSh8H%2BkFKgLeimwL6Nc2BEBCOZelj%2BZpXVWH6s852TEfVHJ6suFhX%2BDbMsEeEbsxKx72ec%2FVVbkPen0NotM2S%2FVlDQ4u%2BNPmFPDK3fRJKU%2Bn5WT5qp5DP%2FkpABeHzIwxw1ynbaOdtqlsk4ZzoQa7JxMX9bMA%2FqcDwUJ1bb2nRWXn%2BHrMFMU1uCthKDSKw%2BXp1VJlDgyXP5rnnkht7LxNS3QKJE%2Bx6CByTrZozmw1Xqr0uv0y8WQC1izmxa5Ur%2F%2FTcwNWLG0JAhR9Nq1Hlx0xr6zdwfmwIUZrPjbxhUPKvP3br76M2UmwOMpa6qTJonY%2BtUK2z2qHWab%2BnonqRG%2BFOluSTVL39e5hCrPJX5x01gvlychU16io%2FqWoztY4zD6%2FuLHBjqyAfF%2BuCW2gBYT3UyDwqzjt4gs9fjdqkyKYaCrQXcOfbhJCYWdSI6sdYB1azino96usY%2FHWGXztulIJPH0RAqFOrT78WueldVcB%2BBauphjANMJl6e78TAkcTDP2z2SWP6d8Kj9B1v0ZlqHEUM6ILZba4nC8t2n99KC1MtMOGpBfg9cen78D321QSqquDIK56iqcoIFQEm%2F2bx41LLMK9epw057%2BC9%2FPfiP0mYmU6RfS%2Btl38c%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20251022T121533Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTY5V65VY3D%2F20251022%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=5f31ae584663c7575eb5a03a1bf0fc6c4c4c697c47bd772bbaf1fcb79ba3a2ca&hash=72dc8263620d75ac5d438545cbc222a918d001f7efd54fbe1a0f39c7b52d74f2&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S2352710224008155&tid=spdf-04f272be-6d88-491a-af00-d514cf821c41&sid=8992e5607b1eb84ecb0a0be4fbe8c4ba0c46gxrqb&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&rh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=1c165c5a5d560a050103&rr=9928ebba7fbdd5e5&cc=fr
#
#
# Article 2:  Artificial Intelligence for Energy Efficiency in the Building Sector
#
# https://arxiv.org/pdf/2412.04045

# %% [markdown]
# # 1. Data Loading and Initial Setup

# %%
import os
os.makedirs("../data/GREENprojet/ashrae/", exist_ok=True)
# it creates the folder if it doesn't already exist

# %%
# Uncomment the code below only if you need to convert feather files
"""
mapping = {
    "/data/GREENprojet/ashrae/weather_train.feather": "weather_train.csv",
    "/data/GREENprojet/ashrae/weather_test.feather": "weather_test.csv",
    "/data/GREENprojet/ashrae/train.feather": "train.csv",
    "/data/GREENprojet/ashrae/building_metadata.feather": "building_metadata.csv",
    "/data/GREENprojet/ashrae/test.feather": "test.csv",
    "/data/GREENprojet/ashrae/sample_submission.feather": "sample_submission.feather.csv"}

for feather_file, csv_file in mapping.items():
    try:
        df = pd.read_feather(feather_file)
        df.to_csv(f"../data/GREENprojet/ashrae/{csv_file}", index=False)
        print(f"Converted: {csv_file}")
    except FileNotFoundError:
        print(f"File not found: {feather_file}")
    except Exception as e:
        print(f"Error while converting {csv_file}: {e}")
"""

print("The CSV files are already available in data/GREENprojet/ashrae/")
print("This cell can be ignored.")
# Out:
# The CSV files are already available in data/GREENprojet/ashrae/
# This cell can be ignored.

# %%
import pandas as pd

# we define the data types for each column to reduce memory usage
dtypes = {
    'site_id': 'int8',
    'air_temperature': 'float32',
    'cloud_coverage': 'float32',
    'dew_temperature': 'float32',
    'precip_depth_1_hr': 'float32',
    'sea_level_pressure': 'float32',
    'wind_direction': 'float32',
    'wind_speed': 'float32'}

weather_file = '../data/GREENprojet/ashrae/weather_train.csv'
parse_dates = ['timestamp']

weather_df = pd.read_csv(
    weather_file,
    dtype=dtypes,
    parse_dates=parse_dates,
    low_memory=True)

weather_df.head()
# Out:
#    site_id           timestamp  air_temperature  cloud_coverage  \
# 0        0 2016-01-01 00:00:00        25.000000             6.0
# 1        0 2016-01-01 01:00:00        24.400000             NaN
# 2        0 2016-01-01 02:00:00        22.799999             2.0
# 3        0 2016-01-01 03:00:00        21.100000             2.0
# 4        0 2016-01-01 04:00:00        20.000000             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                NaN         1019.700012             0.0
# 1             21.1               -1.0         1020.200012            70.0
# 2             21.1                0.0         1020.200012             0.0
# 3             20.6                0.0         1020.099976             0.0
# 4             20.0               -1.0         1020.000000           250.0
#
#    wind_speed
# 0         0.0
# 1         1.5
# 2         0.0
# 3         0.0
# 4         2.6

# %%
# load the train.csv file
#this file contains the energy consumption values for training the model

# we define data types for some columns to make the file lighter in memory
train_dtypes = {
    'building_id': 'int16',
    'meter': 'int8',
    'meter_reading': 'float32'}

train_file = '../data/GREENprojet/ashrae/train.csv'

train_df = pd.read_csv(
    train_file,
    dtype=train_dtypes,
    parse_dates=['timestamp'], #convert 'timestamp' into a datetime format
    low_memory=False)

print(f"Shape: {train_df.shape[0]:,} rows and {train_df.shape[1]} columns")

train_df.head()
# Out:
# Shape: 20,216,100 rows and 4 columns
#    building_id  meter  timestamp  meter_reading
# 0            0      0 2016-01-01            0.0
# 1            1      0 2016-01-01            0.0
# 2            2      0 2016-01-01            0.0
# 3            3      0 2016-01-01            0.0
# 4            4      0 2016-01-01            0.0

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# In this section, we make a surface-level exploration as we only look at the buildings metadats and weather data. We will go into more detail in the following sections

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# display information about the weather dataset
print("weather data info:")
print(weather_df.info())
print("\nweather data description:")
print(weather_df.describe())
print("\nweather data missing values:")
print(weather_df.isnull().sum())

#plotting distributions of major weather features
features_to_plot = ['air_temperature', 'dew_temperature','cloud_coverage', 'precip_depth_1_hr','sea_level_pressure', 'wind_direction', 'wind_speed']

plt.figure(figsize=(20, 14))
for i, feature in enumerate(features_to_plot):
    plt.subplot(3, 3, i+1)
    sns.histplot(weather_df[feature].dropna(), kde=True, bins=50)
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# time series trends for air_temperature
plt.figure(figsize=(16,6))
for site in weather_df['site_id'].unique()[:3]:
    site_df = weather_df[weather_df['site_id'] == site]
    plt.plot(site_df['timestamp'], site_df['air_temperature'], label=f'Site {site}', alpha=0.7)
plt.title("Air temperature over time")
plt.xlabel("timestamp")
plt.ylabel("air temperature (°C)")
plt.legend()
plt.show()



# heatmap of missing values
plt.figure(figsize=(10,6))
sns.heatmap(weather_df.sample(1000).isnull(), cbar=False, cmap='viridis')
plt.title("missing values heatmap (sample of 1000 rows)")
plt.show()

print("missing values in the weather data")
print(weather_df.isnull().sum())
print("\nrange of air temperatures recorded")
print(weather_df['air_temperature'].describe())
# Out:
# weather data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139773 entries, 0 to 139772
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   site_id             139773 non-null  int8
#  1   timestamp           139773 non-null  datetime64[ns]
#  2   air_temperature     139718 non-null  float32
#  3   cloud_coverage      70600 non-null   float32
#  4   dew_temperature     139660 non-null  float32
#  5   precip_depth_1_hr   89484 non-null   float32
#  6   sea_level_pressure  129155 non-null  float32
#  7   wind_direction      133505 non-null  float32
#  8   wind_speed          139469 non-null  float32
# dtypes: datetime64[ns](1), float32(7), int8(1)
# memory usage: 4.9 MB
# None
#
# weather data description:
#              site_id                      timestamp  air_temperature  \
# count  139773.000000                         139773    139718.000000
# ...

# %% [markdown]
# The weather data shows a big amount of missing values, especially in some columns like 'cloud_coverage' and 'precip_depth_1_hr'. Air temperature has a reasonable range and no extreme outliers. Some sites have distinct temperature trends over time.

# %%
#we remove the rows where meter_reading is zero or missing

cleaned_train_df = train_df.dropna(subset=['meter_reading'])

# remove the rows where meter_reading is exactly zero
cleaned_train_df = cleaned_train_df[cleaned_train_df['meter_reading'] != 0]

print("original training set shape:", train_df.shape)
print(" shape after :", cleaned_train_df.shape)
# Out:
# original training set shape: (20216100, 4)
#  shape after : (18342124, 4)

# %%
#load the dataset about the buildings
building_metadata_file= '../data/GREENprojet/ashrae/building_metadata.csv'

building_dtypes = {
    'site_id': 'int8',
    'building_id': 'int16',
    'square_feet': 'int32',
    'year_built': 'float32',
    'floor_count': 'float32'}

building_metadata_df = pd.read_csv(
    building_metadata_file,
    dtype=building_dtypes,
    low_memory=False)

print(f"{building_metadata_df.shape[0]:,} buildings and {building_metadata_df.shape[1]} features")

display(building_metadata_df.head(10))
# Out:
# 1,449 buildings and 6 features
#    site_id  building_id          primary_use  square_feet  year_built  \
# 0        0            0            Education         7432      2008.0
# 1        0            1            Education         2720      2004.0
# 2        0            2            Education         5376      1991.0
# 3        0            3            Education        23685      2002.0
# 4        0            4            Education       116607      1975.0
# 5        0            5            Education         8000      2000.0
# 6        0            6  Lodging/residential        27926      1981.0
# 7        0            7            Education       121074      1989.0
# 8        0            8            Education        60809      2003.0
# 9        0            9               Office        27000      2010.0
#
#    floor_count
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# ...

# %%
# Informations about the buildings dataset

print("\nInformation about the columns:")
print(building_metadata_df.info())

print("\nStatistics:")
print(building_metadata_df.describe())

print("\nMissing values:")
missing_values = building_metadata_df.isnull().sum()
missing_percent = (missing_values / len(building_metadata_df)) * 100
missing_df = pd.DataFrame({
    'Missing values': missing_values,
    'Percentage (%)': missing_percent})
print(missing_df[missing_df['Missing values'] > 0])

print(f"\nnumber of unique buildings: {building_metadata_df['building_id'].nunique()}")
print(f"number of unique sites: {building_metadata_df['site_id'].nunique()}")
print(f"number of unique primary uses: {building_metadata_df['primary_use'].nunique()}")

print("\nDistribution of buildings by site:")
print(building_metadata_df['site_id'].value_counts().sort_index())
# Out:
# Information about the columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   site_id      1449 non-null   int8
#  1   building_id  1449 non-null   int16
#  2   primary_use  1449 non-null   object
#  3   square_feet  1449 non-null   int32
#  4   year_built   675 non-null    float32
#  5   floor_count  355 non-null    float32
# dtypes: float32(2), int16(1), int32(1), int8(1), object(1)
# memory usage: 32.7+ KB
# None
#
# Statistics:
#            site_id  building_id    square_feet   year_built  floor_count
# count  1449.000000  1449.000000    1449.000000   675.000000   355.000000
# mean      6.952381   724.000000   92111.776398  1967.957031     3.740845
# std       5.003432   418.434583  110769.950997    31.054029     3.333683
# min       0.000000     0.000000     283.000000  1900.000000     1.000000
# ...

# %%
#AI have been used in this cell to have the get cleanest plot and prints
# Visualization of building feature distributions

fig, axes = plt.subplots(2, 3, figsize=(20, 12))

# 1. Distribution of square footage (square_feet)
axes[0, 0].hist(building_metadata_df['square_feet'].dropna(), bins=50, color='skyblue', edgecolor='black')
axes[0, 0].set_title('Distribution of Square Footage (square_feet)', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Square Footage (sq ft)')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].ticklabel_format(style='plain', axis='x')

# 2. Distribution of year built (year_built)
axes[0, 1].hist(building_metadata_df['year_built'].dropna(), bins=50, color='lightcoral', edgecolor='black')
axes[0, 1].set_title('Distribution of Year Built', fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Year Built')
axes[0, 1].set_ylabel('Frequency')

# 3. Distribution of floor count (floor_count)
axes[0, 2].hist(building_metadata_df['floor_count'].dropna(), bins=50, color='lightgreen', edgecolor='black')
axes[0, 2].set_title('Distribution of Floor Count', fontsize=14, fontweight='bold')
axes[0, 2].set_xlabel('Number of Floors')
axes[0, 2].set_ylabel('Frequency')

# 4. Boxplot of square footage
axes[1, 0].boxplot(building_metadata_df['square_feet'].dropna(), vert=True)
axes[1, 0].set_title('Boxplot of Square Footage', fontsize=14, fontweight='bold')
axes[1, 0].set_ylabel('Square Footage (sq ft)')

# 5. Boxplot of year built
axes[1, 1].boxplot(building_metadata_df['year_built'].dropna(), vert=True)
axes[1, 1].set_title('Boxplot of Year Built', fontsize=14, fontweight='bold')
axes[1, 1].set_ylabel('Year Built')

# 6. Boxplot of floor count
axes[1, 2].boxplot(building_metadata_df['floor_count'].dropna(), vert=True)
axes[1, 2].set_title('Boxplot of Floor Count', fontsize=14, fontweight='bold')
axes[1, 2].set_ylabel('Number of Floors')

plt.tight_layout()
plt.show()

# Statistics about oldest and newest buildings
print("\nTEMPORAL ANALYSIS OF BUILDINGS")
print("="*60)
oldest_year = building_metadata_df['year_built'].min()
newest_year = building_metadata_df['year_built'].max()
print(f"Oldest building: {oldest_year}")
print(f"Newest building: {newest_year}")
print(f"Range: {int(newest_year - oldest_year)} years")

# Statistics about building size
print("\nBUILDING SIZE ANALYSIS")
print("="*60)
print(f"Minimum square footage: {building_metadata_df['square_feet'].min():,.0f} sq ft")
print(f"Maximum square footage: {building_metadata_df['square_feet'].max():,.0f} sq ft")
print(f"Median square footage: {building_metadata_df['square_feet'].median():,.0f} sq ft")

# Statistics about floor count
print("\nFLOOR COUNT ANALYSIS")
print("="*60)
print(f"Minimum number of floors: {building_metadata_df['floor_count'].min():.0f}")
print(f"Maximum number of floors: {building_metadata_df['floor_count'].max():.0f}")
print(f"Median number of floors: {building_metadata_df['floor_count'].median():.0f}")
# Out:
# TEMPORAL ANALYSIS OF BUILDINGS
# ...
# Oldest building: 1900.0
# Newest building: 2017.0
# Range: 117 years
#
# BUILDING SIZE ANALYSIS
# ...
# Minimum square footage: 283 sq ft
# Maximum square footage: 875,000 sq ft
# Median square footage: 57,673 sq ft
#
# FLOOR COUNT ANALYSIS
# ...
# Minimum number of floors: 1
# Maximum number of floors: 26
# Median number of floors: 3

# %% [markdown]
# # 3. Energy consumption analysis

# %% [markdown]
# ### Primary use vs meter readings
#
# We will now investigate whether the feature `primary_use` can be selected to predict meter readings.

# %%
# Analysis of primary use (primary_use)


print("primary use analysis of buildings")

#count the number of buildings by primary use
primary_use_counts =building_metadata_df['primary_use'].value_counts()
print("\nnumber of buildings by primary use:")
print(primary_use_counts)

#distribution of primary uses
fig, axes =plt.subplots(1, 2, figsize=(20, 6))

#bar chart
primary_use_counts.plot(kind='bar', ax=axes[0], color='teal',edgecolor='black')
axes[0].set_title('Number of buildings by primary use',fontsize=16, fontweight='bold')
axes[0].set_xlabel('Primary use', fontsize=12)
axes[0].set_ylabel('Number of buildings', fontsize=12)
axes[0].tick_params(axis='x',rotation=45)
axes[0].grid(axis='y',alpha=0.3)


#pie chart for top 10
top_10_uses =primary_use_counts.head(10)
colors =plt.cm.tab20c(range(len(top_10_uses)))
axes[1].pie(top_10_uses, labels=top_10_uses.index, autopct='%1.1f%%', startangle=90, colors=colors)
axes[1].set_title('top 10 primary uses (% of buildings)', fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# primary use analysis of buildings
#
# number of buildings by primary use:
# primary_use
# Education                        549
# Office                           279
# Entertainment/public assembly    184
# Public services                  156
# Lodging/residential              147
# Other                             25
# Healthcare                        23
# Parking                           22
# Warehouse/storage                 13
# Manufacturing/industrial          12
# Retail                            11
# Services                          10
# Technology/science                 6
# Food sales and service             5
# Utility                            4
# Religious worship                  3
# Name: count, dtype: int64

# %% [markdown]
# The majority of buildings have 'Education' as the primary use, followed by 'Office'.

# %%
# merge building metadata with energy consumption data


# Merge cleaned_train_df with building_metadata_df on building_id
merged_df = cleaned_train_df.merge(
    building_metadata_df,
    on='building_id',
    how='left')

print(f"Shape of merged dataframe: {merged_df.shape[0]:,} rows and {merged_df.shape[1]} columns")

#check the first few rows
print("\nPreview of merged data:")
merged_df.head(10)
# Out:
# Shape of merged dataframe: 18,342,124 rows and 9 columns
#
# Preview of merged data:
#    building_id  meter  timestamp  meter_reading  site_id primary_use  \
# 0           46      0 2016-01-01      53.239700        0      Retail
# 1           74      0 2016-01-01      43.001301        0     Parking
# 2           93      0 2016-01-01      52.420601        0      Office
# 3          105      0 2016-01-01      23.303600        1   Education
# 4          106      0 2016-01-01       0.374600        1   Education
# 5          107      0 2016-01-01     175.184006        1   Education
# 6          108      0 2016-01-01      91.265297        1   Education
# 7          109      0 2016-01-01      80.930000        1   Education
# 8          110      0 2016-01-01      86.228302        1   Education
# 9          111      0 2016-01-01     167.391998        1   Education
#
#    square_feet  year_built  floor_count
# 0         9045      2016.0          NaN
# 1       387638      1997.0          NaN
# ...

# %%
#analysis of energy consumption by primary use

print("energy consumption by primary use ")

# calculate statistics by primary use using groupby aggregation
primary_use_stats = merged_df.groupby('primary_use')['meter_reading'].agg([
    ('Number of records', 'count'),
    ('Average consumption', 'mean'),
    ('Total consumption', 'sum'),
    ('Median consumption', 'median'),
    ('Standard deviation', 'std')]).sort_values('Average consumption', ascending=False)

print("\nEnergy consumption statistics by primary use:")
print(primary_use_stats)

# visualization: average and total consumption by primary use
fig, axes = plt.subplots(1, 2, figsize=(22, 7))

#average consumption sorted by value
primary_use_stats['Average consumption'].sort_values(ascending=True).plot(
    kind='barh',
    ax= axes[0],
    color ='steelblue',
    edgecolor='black')
axes[0].set_title('Average energy consumption by primary use', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Average consumption (kWh)',fontsize=12)
axes[0].set_ylabel(' primary use', fontsize=12)
axes[0].grid(axis='x', alpha=0.3)

#total consumption
primary_use_stats['Total consumption'].sort_values(ascending=True).plot(
    kind = 'barh',
    ax=axes[1],
    color ='coral',
    edgecolor='black')
axes[1].set_title('Total energy consumption by primary use', fontsize=14, fontweight='bold')
axes[1].set_xlabel('total consumption (kWh)', fontsize=12)
axes[1].set_ylabel('primary use', fontsize=12)
axes[1].ticklabel_format(style='scientific', axis='x', scilimits=(0,0))
axes[1].grid(axis='x',alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# energy consumption by primary use

# %% [markdown]
# The analysis reveals that 'Education' and 'Services' buildings exhibit the highest average energy consumption among all primary uses in the dataset.
# These categories significantly influence the city's overall energy demand, suggesting that targeting energy optimization strategies within these sectors
# could yield substantial efficiency gains. Specifically, focusing on schools, universities, and service-oriented buildings may have the greatest impact on reducing total energy consumption and associated CO₂ emissions in New York’s building stock.

# %% [markdown]
# ### Energy consumption analysis by site (Site ID)
#
# We will now analyze whether the `site_id` and `building_id` features affect energy consumption in order to **detect outliers**.
#
# The meter readings were recorded on **16 different sites**. Let's analyze the differences in energy consumption between these sites.

# %%
#energy consumption analysis by site

print("energy consumption analysis by site")

# calculate statistics by site using groupby aggregation
site_stats= merged_df.groupby('site_id')['meter_reading'].agg([
    ('Number of records', 'count'),
    ('Average consumption', 'mean'),
    ('Median consumption', 'median'),
    ('Total consumption', 'sum'),
    ('Standard deviation', 'std'),
    ('Min', 'min'),
    ('Max', 'max')]).sort_values('Average consumption', ascending=False)

print("\nConsumption statistics by site:")
print(site_stats)

#calculate coefficient of variation (CV) to identify variability
site_stats['Coefficient of variation (%)']=(site_stats['Standard deviation'] / site_stats['Average consumption']) * 100

print("\nSites with highest variability (coefficient of variation):")
print(site_stats[['Average consumption', 'Coefficient of variation (%)']].sort_values('Coefficient of variation (%)', ascending=False))

# Number of buildings per site
buildings_per_site =building_metadata_df.groupby('site_id').size().reset_index(name='Number of buildings')
print("\nnumber of buildings per site:")

print(buildings_per_site)
# Out:
# energy consumption analysis by site
#
# Consumption statistics by site:
#          Number of records  Average consumption  Median consumption  \
# site_id
# 13                 2391249         15436.698242          159.919998
# 7                   276911          1612.087402          879.099976
# 6                   556565          1189.453613          128.500000
# 0                   714587           828.470459          296.480011
# 14                 2228990           740.684814          238.531006
# 10                  325255           586.919067           59.620201
# 15                 1731066           316.212372           92.849998
# 9                  2492003           282.843933          135.000000
# 2                  2277505           204.188721           91.930000
# 11                   94389           188.993088          177.171005
# 4                   742867           182.033386           71.000000
# 1                   514165           160.929398           90.000000
# ...

# %%
#visualization of consumption by site

fig, axes = plt.subplots(2, 2, figsize=(20, 14))

# average consumption per site
site_stats['Average consumption'].plot(
    kind='bar',
    ax=axes[0, 0],
    color='steelblue',
    edgecolor='black')
axes[0, 0].set_title('Average energy consumption by site', fontsize=14, fontweight='bold')
axes[0, 0].set_xlabel('Site ID', fontsize=12)
axes[0, 0].set_ylabel('Average consumption (kWh)', fontsize=12)
axes[0,0].grid(axis='y', alpha=0.3)
axes[0,0].tick_params(axis='x', rotation=0)


# total consumption per site
site_stats['Total consumption'].plot(
    kind='bar',
    ax=axes[0, 1],
    color='coral',
    edgecolor='black')
axes[0,1].set_title('Total energy consumption by site',fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('Site ID', fontsize=12)
axes[0, 1].set_ylabel('Total consumption (kWh)', fontsize=12)
axes[0, 1].ticklabel_format(style='scientific', axis='y', scilimits=(0,0))
axes[0, 1].grid(axis='y', alpha=0.3)
axes[0, 1].tick_params(axis='x', rotation=0)

# boxplot of consumption by site (log scale) ,using sample for performance
sample_sites = merged_df.sample(n=min(100000, len(merged_df)), random_state=42)
sample_sites.boxplot(
    column='meter_reading',
    by='site_id',
    ax=axes[1, 0],
    patch_artist=True)
axes[1, 0].set_title('Distribution of consumption by site (log scale)', fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel('Site ID', fontsize=12)
axes[1, 0].set_ylabel(' consumption (kWh)', fontsize=12)
axes[1, 0].set_yscale('log')
plt.suptitle('')

# coefficient of variation by site
site_stats['Coefficient of variation (%)'].sort_values().plot(
    kind='barh',
    ax=axes[1, 1],
    color='lightgreen',
    edgecolor='black')
axes[1, 1].set_title('Consumption variability by site (coefficient of variation)', fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel('coefficient of variation (%)', fontsize=12)
axes[1, 1].set_ylabel('Site ID', fontsize=12)
axes[1, 1].grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here, we observe notable differences in energy consumption between different locations. Some sites have consistently higher or lower average and total consumption, indicating that local factors (such as building usage types, climate, or operational practices) play a major role. The coefficient of variation also highlights that variability in energy usage can differ widely, possibly due to differing usage patterns or occupancy. Sites identified as outliers in these metrics may warrant further investigation—they could be targets for energy optimization, or they may reflect atypical buildings, measurement issues, or unique energy needs.

# %% [markdown]
# Similarly, we could perform an analysis comparing consumption to building age, number of floors, square footage...

# %% [markdown]
# # 4. Outlier Detection

# %% [markdown]
# ### Outlier Detection by Site
#
# Let's use statistical methods to identify sites with abnormal behavior in terms of energy consumption.

# %%
#Outlier detection by site using the IQR (Interquartile Range) method

print("Outlier detection by site")

# calculate Q1, Q3 and IQR for average consumption by site
Q1 =site_stats['Average consumption'].quantile(0.25)
Q3 =site_stats['Average consumption'].quantile(0.75)
IQR =Q3- Q1

#define thresholds for outliers
lower_bound= Q1 -1.5 *IQR
upper_bound=Q3 + 1.5 * IQR

print(f"\nStatistics for outlier detection:")
print(f"Q1 (25th percentile): {Q1:.2f} kWh")
print(f"Q3 (75th percentile):{Q3:.2f} kWh")
print(f"IQR: {IQR:.2f} kWh")
print(f"Lower bound: {lower_bound:.2f} kWh")
print(f"Upper bound:{upper_bound:.2f} kWh")

# identify outlier sites
site_stats['Is_Outlier'] =(site_stats['Average consumption'] < lower_bound) | (site_stats['Average consumption'] > upper_bound)
outlier_sites = site_stats[site_stats['Is_Outlier']]

print(f"\noutlier sites detected :{len(outlier_sites)} site(s)")
if len(outlier_sites) >0 :

    print("\nDetails of outlier sites:")
    print(outlier_sites[['Average consumption', 'Median consumption', 'Standard deviation', 'Number of records']])

    # classify outliers
    high_outliers =outlier_sites[outlier_sites['Average consumption']> upper_bound]
    low_outliers = outlier_sites[outlier_sites['Average consumption'] < lower_bound]

    if len(high_outliers)> 0: 
        print(f"\nSites with high abnormal consumption:{list(high_outliers.index)}")
    if len(low_outliers) >0:
        print(f"\nSites with low abnormal consumption: {list(low_outliers.index)}")
else:
    print("No outlier sites detected with the IQR method")

# visualization
fig, ax= plt.subplots(figsize=(14, 6))
colors = ['red' if outlier else 'steelblue' for outlier in site_stats['Is_Outlier']]
bars = ax.bar(site_stats.index.astype(str), site_stats['Average consumption'], color=colors, edgecolor='black')

ax.axhline(y=upper_bound, color='red', linestyle='--', linewidth=2, label=f'Upper bound ({upper_bound:.0f} kWh)')
ax.axhline(y=lower_bound, color='orange', linestyle='--', linewidth=2, label=f'Lower bound ({lower_bound:.0f} kWh)')
ax.axhline(y=site_stats['Average consumption'].median(), color='green', linestyle='-', linewidth=2, label=f'Median ({site_stats["Average consumption"].median():.0f} kWh)')

ax.set_title('Outlier site detection :average consumption', fontsize=16, fontweight='bold')
ax.set_xlabel('Site ID', fontsize=12)
ax.set_ylabel('Average consumption (kWh)', fontsize=12)
ax.legend(fontsize=11)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Outlier detection by site
#
# Statistics for outlier detection:
# Q1 (25th percentile): 152.22 kWh
# Q3 (75th percentile):762.63 kWh
# IQR: 610.41 kWh
# Lower bound: -763.40 kWh
# Upper bound:1678.25 kWh
#
# outlier sites detected : 1 site(s)
#
# Details of outlier sites:
#          Average consumption  Median consumption  Standard deviation  \
# site_id
# 13              15436.698242          159.919998       445201.207866
#
#          Number of records
# site_id
# 13                 2391249
#
# Sites with high abnormal consumption: [13]

# %% [markdown]
# ### Energy consumption analysis by building (building ID)
#
# Let's now examine the differences in energy consumption among the **1449 buildings** to identify buildings with abnormal energy behavior.

# %%
# energy consumption analysis by building

print("energy consumption analysis by building")

#calculate statistics by building using groupby aggregation
building_stats = merged_df.groupby('building_id')['meter_reading'].agg([
    ('Number of records','count'),
    ('Average consumption', 'mean'),
    ('Median consumption', 'median'),
    ('Total consumption', 'sum'),
    ('Standard deviation', 'std'),
    ('Min', 'min'),
    ('Max', 'max')]).sort_values('Average consumption', ascending=False)

#top 10 head
print(f"\nTotal number of buildings analyzed: {len(building_stats)}")
print("\nTOP 10 buildings with highest average consumption:")
print(building_stats.head(10))

#top 10 tail
print("\nTOP 10 buildings with lowest average consumption:")
print(building_stats.tail(10))

#statistics
print("\n statistics on buildings :")
print(f"global average consumption: {building_stats['Average consumption'].mean():.2f} kWh")
print(f"global median consumption: {building_stats['Average consumption'].median():.2f} kWh")
print(f"global standard deviation: {building_stats['Average consumption'].std():.2f} kWh")
print(f"minimum consumption: {building_stats['Average consumption'].min():.2f} kWh")
print(f"maximum consumption: {building_stats['Average consumption'].max():.2f} kWh")
print(f"max/min ratio: {building_stats['Average consumption'].max() / building_stats['Average consumption'].min():.2f}x")
# Out:
# energy consumption analysis by building
#
# Total number of buildings analyzed: 1449
#
# TOP 10 buildings with highest average consumption:
#              Number of records  Average consumption  Median consumption  \
# building_id
# 1099                     17566         1.907446e+06          985.697021
# 778                       9616         4.579986e+04          239.375000
# 1197                     17090         2.284378e+04          339.812012
# 1168                     25925         1.653362e+04         2398.260010
# 1159                     25819         1.217094e+04         1715.310059
# 1148                     26229         1.005966e+04         1232.099976
# 1021                     14212         9.968012e+03          169.250000
# 1088                     26289         7.921117e+03         2884.429932
# 1284                     26027         7.402598e+03         6396.790039
# 76                       12676         5.774107e+03         4600.930176
#
# ...

# %%
# Visualization of consumption distribution by building

fig, axes = plt.subplots(2, 2, figsize=(20, 14))

#histogram of average consumption per building, using log scale on y-axis
axes[0, 0].hist(building_stats['Average consumption'], bins=100, color='skyblue', edgecolor='black')
axes[0, 0].set_title('Distribution of average consumption per building', fontsize=14, fontweight='bold')
axes[0,0].set_xlabel('average consumption (kWh)',fontsize=12)
axes[0, 0].set_ylabel('number of buildings', fontsize=12)
axes[0, 0].set_yscale('log')
axes[0, 0].grid(axis='y', alpha=0.3)

# histogram with logarithmic scale on x axis for better visualization
axes[0, 1].hist(np.log1p(building_stats['Average consumption']), bins=100, color='lightcoral', edgecolor='black')
axes[0, 1].set_title('Distribution of log(1 + average consumption) per building', fontsize=14, fontweight='bold')
axes[0, 1].set_xlabel('log(1 + average consumption)', fontsize=12)
axes[0, 1].set_ylabel('number of buildings', fontsize=12)
axes[0, 1].grid(axis='y', alpha=0.3)

# top 30 buildings with highest consumption
top_30_buildings = building_stats.head(30)
axes[1,0].barh(range(len(top_30_buildings)), top_30_buildings['Average consumption'], color='steelblue', edgecolor='black')
axes[1, 0].set_yticks(range(len(top_30_buildings)))
axes[1, 0].set_yticklabels([f"Bldg. {bid}" for bid in top_30_buildings.index])
axes[1, 0].set_title('top 30 buildings with highest consumption', fontsize=14, fontweight='bold')
axes[1, 0].set_xlabel(' average consumption (kWh)', fontsize=12)
axes[1, 0].grid(axis='x', alpha=0.3)
axes[1, 0].invert_yaxis()

# boxplot of average consumption per building using log scale
axes[1, 1].boxplot(building_stats['Average consumption'], vert=True)
axes[1,1].set_title('boxplot of average consumption per building', fontsize=14, fontweight='bold')
axes[1, 1].set_ylabel('average consumption (kWh)', fontsize=12)
axes[1, 1].set_yscale('log')
axes[1, 1].grid(axis='y', alpha=0.3)


plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Weather Impact Analysis

# %% [markdown]
# ## Weather characteristics vs. meter readings
#
# The dataset also contains several weather variables that are recorded at the site level, thus affecting all buildings at the same sites.

# %%
# review and analysis of the weather dataset as a minder of what have been already done

dtypes ={
    'site_id': 'int8',
    'air_temperature': 'float32',
    'cloud_coverage': 'float32',
    'dew_temperature': 'float32',
    'precip_depth_1_hr': 'float32',
    'sea_level_pressure': 'float32',
    'wind_direction': 'float32',
    'wind_speed': 'float32'}

weather_file = "../data/GREENprojet/ashrae/weather_train.csv"

# load the dataset
weather_df = pd.read_csv(
    weather_file,
    dtype=dtypes,
    parse_dates=['timestamp'],
    low_memory=True)

print(f"\nWeather dataset dimensions: {weather_df.shape[0]:,} rows and {weather_df.shape[1]} columns")

# statistics
print("\n statistics of weather characteristics :")
print(weather_df.describe())

# missing values
missing_weather = weather_df.isnull().sum()
missing_weather_pct = (missing_weather / len(weather_df)) * 100

missing_df_weather = pd.DataFrame({
    "Missing values": missing_weather,
    "Percentage (%)": missing_weather_pct})

print("\nMissing values per variable:")
print(missing_df_weather)

#time coverage
print("\nTime period:")
print(f"Start date: {weather_df['timestamp'].min()}")
print(f"End date: {weather_df['timestamp'].max()}")
print(f" duration: {(weather_df['timestamp'].max() - weather_df['timestamp'].min()).days} days")
print(f"Number of sites: {weather_df['site_id'].nunique()}")
# Out:
# Weather dataset dimensions: 139,773 rows and 9 columns
#
#  statistics of weather characteristics :
#              site_id                      timestamp  air_temperature  \
# count  139773.000000                         139773    139718.000000
# mean        7.478977  2016-07-02 07:17:57.942092032        14.418107
# min         0.000000            2016-01-01 00:00:00       -28.900000
# 25%         3.000000            2016-04-02 02:00:00         7.200000
# 50%         7.000000            2016-07-02 09:00:00        15.000000
# 75%        11.000000            2016-10-01 16:00:00        22.200001
# max        15.000000            2016-12-31 23:00:00        47.200001
# std         4.604744                            NaN        10.626660
#
#        cloud_coverage  dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# count    70600.000000    139660.000000       89484.000000       129155.000000
# mean         2.149306         7.350158           0.983047         1016.158081
# ...

# %%
# Visualization of weather variable distributions (this was partially done earlier in the notebook)

weather_features = [
    'air_temperature', 'dew_temperature', 'cloud_coverage',
    'precip_depth_1_hr', 'sea_level_pressure', 'wind_direction', 'wind_speed']

fig, axes = plt.subplots(3, 3, figsize=(20, 16))
axes = axes.flatten()

for i, feature in enumerate(weather_features):
    data = weather_df[feature].dropna()
    axes[i].hist(data, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
    axes[i].set_title(f'Distribution of {feature}', fontsize=12, fontweight='bold')
    axes[i].set_xlabel(feature, fontsize=10)
    axes[i].set_ylabel('Frequency', fontsize=10)
    axes[i].grid(axis='y', alpha=0.3)

    # we add statistics : mean and median lines
    mean_val = data.mean()
    median_val = data.median()
    axes[i].axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.1f}')
    axes[i].axvline(median_val, color='green', linestyle='--', linewidth=2, label=f'Median: {median_val:.1f}')
    axes[i].legend(fontsize=8)

#remove unused axes
for j in range(len(weather_features), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# The 7 weather characteristics have been visualized.

# %% [markdown]
# Weather analysis shows temperature varies widely and is likely the most important driver of energy use. Other weather features have missing data and less pronounced effects; careful filling of missing values is needed. Overall, temperature, wind, and pressure offer useful signals, with temperature being most impactful.

# %% [markdown]
# # 6. Data preprocessing and feature engineering

# %% [markdown]
# Completing the missing values

# %%
weather_new = weather_df.copy()

# make sure timestamp is datetime
weather_new["timestamp"] = pd.to_datetime(weather_new["timestamp"])

#add month and day
weather_new["month"] = weather_new["timestamp"].dt.month
weather_new["day"]   = weather_new["timestamp"].dt.day

# columns where we want to fill missing values
weather_cols = [
    "air_temperature",
    "cloud_coverage",
    "dew_temperature",
    "precip_depth_1_hr",
    "sea_level_pressure",
    "wind_direction",
    "wind_speed"]

#fill the NaN with monthly mean for each site
weather_new[weather_cols] = (
    weather_new
    .groupby(["site_id", "month"])[weather_cols]
    .transform(lambda x: x.fillna(x.mean())))

#for the remaining NaN, we use the mean of each site
for i in weather_cols:
    weather_new[i] = (
        weather_new
        .groupby("site_id")[i]
        .transform(lambda x: x.fillna(x.mean())))

    # if there are still NaN, we use global mean of the column
    global_mean = weather_new[i].mean()
    weather_new[i].fillna(global_mean, inplace=True)

# remove the columns month, day
weather_new.drop(columns=["month", "day"], inplace=True)

# check that nothing is missing
print(weather_new.isnull().sum())
# Out:
# site_id               0
# timestamp             0
# air_temperature       0
# cloud_coverage        0
# dew_temperature       0
# precip_depth_1_hr     0
# sea_level_pressure    0
# wind_direction        0
# wind_speed            0
# dtype: int64
# C:\Users\sulta\AppData\Local\Temp\ipykernel_16272\2772903342.py:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather_new[i].fillna(global_mean, inplace=True)

# %% [markdown]
# Time feature engineering

# %%
#function that adds hour, day, weekday and month so the model can understand how energy use changes over time
def add_time_features(df):
    # we make sure timestamp is datetime
    df["timestamp"] = pd.to_datetime(df["timestamp"])

    # create new time features
    df["hour"] = df["timestamp"].dt.hour
    df["day"] = df["timestamp"].dt.day
    df["weekday"] = df["timestamp"].dt.weekday
    df["month"] = df["timestamp"].dt.month
    return df

# %% [markdown]
# Building Age
#
# we saw that the variable year_built alone was not very useful. However, we can use it to calculate the age of the building, which may impact energy consumption.

# %%
# we create a new column for building age
#subtract the construction year from 2016 because the dataset only contains data from 2016, so we calculate the building age at that moment
building_metadata_df["building_age"] = 2016 - building_metadata_df["year_built"]

# replace negative or missing ages with the median age
median_age = building_metadata_df["building_age"].median()
building_metadata_df["building_age"].fillna(median_age, inplace=True)
# Out:
# C:\Users\sulta\AppData\Local\Temp\ipykernel_16272\2227131057.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   building_metadata_df["building_age"].fillna(median_age, inplace=True)

# %% [markdown]
# Encoding categorical columns

# %%
from sklearn.preprocessing import LabelEncoder

# we create a label encoder
encoder = LabelEncoder()
#convert primary_use text into numbers
building_metadata_df["primary_use_encoded"] = encoder.fit_transform(
    building_metadata_df["primary_use"])
print(building_metadata_df[["primary_use", "primary_use_encoded"]].head(20))
# Out:
#                       primary_use  primary_use_encoded
# 0                       Education                    0
# 1                       Education                    0
# 2                       Education                    0
# 3                       Education                    0
# 4                       Education                    0
# 5                       Education                    0
# 6             Lodging/residential                    4
# 7                       Education                    0
# 8                       Education                    0
# 9                          Office                    6
# 10  Entertainment/public assembly                    1
# 11                      Education                    0
# 12            Lodging/residential                    4
# 13                      Education                    0
# 14                      Education                    0
# 15                         Office                    6
# ...

# %% [markdown]
# the text categories in "primary_use" were changed into numbers, so the model can work with them. For example, "education" became 0, "entertainment/public assembly" became 1, "lodging/residential" became 4, "office" became 6

# %% [markdown]
# Feature selection : choosing input & target variables

# %%
#we select the columns that will be useful for prediction
# we keep weather data, building info and time features
selected_features = [
    "building_id",
    "site_id",
    "meter",
    "building_age",
    "square_feet",
    "primary_use_encoded",
    "air_temperature",
    "dew_temperature",
    "wind_speed",
    "sea_level_pressure",
    "hour",
    "day",
    "weekday",
    "month"]

# target variable (what we want to predict)
target = "meter_reading"

print("Features selected for the model:")
print(selected_features)
# Out:
# Features selected for the model:
# ['building_id', 'site_id', 'meter', 'building_age', 'square_feet', 'primary_use_encoded', 'air_temperature', 'dew_temperature', 'wind_speed', 'sea_level_pressure', 'hour', 'day', 'weekday', 'month']

# %% [markdown]
# We selected these features because they were the most important in our EDA. They describe the building, the weather, and the time  which are the three main factors that influence energy consumption.

# %% [markdown]
# Merge the datasets together

# %%
#we add new time features (hour, day, month) to the weather data
weather_new = add_time_features(weather_new)

# join the training data with the building information
merged_df = train_df.merge(
    building_metadata_df,
    on="building_id",
    how="left")
#add the weather data matchnig rows with "site_id" and "timestamp"
merged_df = merged_df.merge(
    weather_new,
    on=["site_id", "timestamp"],
    how="left")

# %%
print(merged_df.columns)
# Out:
# Index(['building_id', 'meter', 'timestamp', 'meter_reading', 'site_id',
#        'primary_use', 'square_feet', 'year_built', 'floor_count',
#        'building_age', 'primary_use_encoded', 'air_temperature',
#        'cloud_coverage', 'dew_temperature', 'precip_depth_1_hr',
#        'sea_level_pressure', 'wind_direction', 'wind_speed', 'hour', 'day',
#        'weekday', 'month'],
#       dtype='object')

# %% [markdown]
# we can see columns from the traind data (building_id, meter...), building file (year_built,floor_count), the weather file (air_temperature,cloud_coverage) and the time features(jour, day...). So the merged dataset was well done.

# %%
print(merged_df.isnull().sum())
# Out:
# building_id                   0
# meter                         0
# timestamp                     0
# meter_reading                 0
# site_id                       0
# primary_use                   0
# square_feet                   0
# year_built             12127645
# floor_count            16709167
# building_age                  0
# primary_use_encoded           0
# air_temperature           90495
# cloud_coverage            90495
# dew_temperature           90495
# precip_depth_1_hr         90495
# sea_level_pressure        90495
# wind_direction            90495
# wind_speed                90495
# hour                      90495
# day                       90495
# weekday                   90495
# month                     90495
# dtype: int64

# %% [markdown]
# we still have some missing values

# %%
#fill building info (year_built and floor_count) with the median

merged_df["year_built"] = merged_df["year_built"].fillna(
    merged_df["year_built"].median())

merged_df["floor_count"] = merged_df["floor_count"].fillna(
    merged_df["floor_count"].median())

# fill the weather columns
weather_cols = [
    "air_temperature",
    "cloud_coverage",
    "dew_temperature",
    "precip_depth_1_hr",
    "sea_level_pressure",
    "wind_direction",
    "wind_speed"]

for i in weather_cols:
    # use median of each site
    merged_df[i] = (
        merged_df
        .groupby("site_id")[i]
        .transform(lambda x: x.fillna(x.median()))
    )
    # if there are still NaN, use global median
    merged_df[i] = merged_df[i].fillna(merged_df[i].median())

print(merged_df.isnull().sum())
# Out:
# building_id                0
# meter                      0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# year_built                 0
# floor_count                0
# building_age               0
# primary_use_encoded        0
# air_temperature            0
# cloud_coverage             0
# dew_temperature            0
# precip_depth_1_hr          0
# sea_level_pressure         0
# wind_direction             0
# wind_speed                 0
# hour                   90495
# day                    90495
# weekday                90495
# month                  90495
# dtype: int64

# %%
# add time features to the merged dataset
merged_df = add_time_features(merged_df)

# check that the new columns are there
print(merged_df.columns)

#check that there are no missing values
print(merged_df[["hour", "day", "weekday", "month"]].isnull().sum())
# Out:
# Index(['building_id', 'meter', 'timestamp', 'meter_reading', 'site_id',
#        'primary_use', 'square_feet', 'year_built', 'floor_count',
#        'building_age', 'primary_use_encoded', 'air_temperature',
#        'cloud_coverage', 'dew_temperature', 'precip_depth_1_hr',
#        'sea_level_pressure', 'wind_direction', 'wind_speed', 'hour', 'day',
#        'weekday', 'month'],
#       dtype='object')
# hour       0
# day        0
# weekday    0
# month      0
# dtype: int64

# %%
print(merged_df.isnull().sum())
# Out:
# building_id            0
# meter                  0
# timestamp              0
# meter_reading          0
# site_id                0
# primary_use            0
# square_feet            0
# year_built             0
# floor_count            0
# building_age           0
# primary_use_encoded    0
# air_temperature        0
# cloud_coverage         0
# dew_temperature        0
# precip_depth_1_hr      0
# sea_level_pressure     0
# wind_direction         0
# wind_speed             0
# hour                   0
# day                    0
# weekday                0
# month                  0
# dtype: int64

# %% [markdown]
# now, we have no missing values

# %% [markdown]
# Train / Validation split (75% / 25%)

# %%
# we sort by time to keep the time order
merged_sorted = merged_df.sort_values("timestamp").reset_index(drop=True)

# inputs X and target y
X = merged_sorted[selected_features]
y = np.log1p(merged_sorted[target]) #we use the log transform to make big values smaller and the data easier to learn for the model

# 75% for training, 25% for validation
split_index = int(len(merged_sorted) * 0.75)

X_train = X.iloc[:split_index]
y_train = y.iloc[:split_index]

X_val = X.iloc[split_index:]
y_val = y.iloc[split_index:]

print("Train size :", X_train.shape)
print(" validation size :", X_val.shape)
# Out:
# Train size : (15162075, 14)
#  validation size : (5054025, 14)

# %%
# root mean squared error
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))

# %% [markdown]
# # 7. Model Training and Evaluation

# %% [markdown]
# Mean model

# %%
from sklearn.metrics import r2_score

# Mean model

mean_value = y_train.mean()

# prediction
y_train_pred_mean = [mean_value for i in range(len(y_train))]
y_val_pred_mean   = [mean_value for i in range(len(y_val))]

#compute rmse
rmse_train_mean = rmse(y_train, y_train_pred_mean)
rmse_val_mean   = rmse(y_val, y_val_pred_mean)

print("Mean model (with log)-train rmse :", rmse_train_mean)
print("Mean model (with log)- val   rmse :", rmse_val_mean)

# compue R²
r2_train_mean = r2_score(y_train, y_train_pred_mean)
r2_val_mean   = r2_score(y_val, y_val_pred_mean)

print("Mean model (with log)-train R²   :", r2_train_mean)
print("Mean model (with log)- val R²   :", r2_val_mean)
# Out:
# Mean model (with log)-train rmse : 2.1603801
# Mean model (with log)- val   rmse : 2.1032665
# Mean model (with log)-train R²   : 0.0
# Mean model (with log)- val R²   : -0.0003763437271118164

# %% [markdown]
# Interpretation :
#
# - train rmse = 2.16 and Val rmse = 2.10: the model makes errors because it always predicts the same value (the mean)
#
# - train R² = 0.0: the model doesn't explain the data at all.
#
# - validation R² ≈ -0.00037: a negative R² means the model is not useful.
#
# So, the mean model performs badly. It doesn't learn anything and gives almost the same error on train and validation.

# %% [markdown]
# During this work, we had a RAM problem because the dataset is very large (more than 15 million rows). Training some models like Linear Regression, LightGBM, or XGBoost on the full data needs a lot of memory. Our computer couldn't process all the rows at once, so the kernel crashed.
# To fix this, we used a smaller sample (1 million rows) for the heaviest models to avoid running out of RAM.

# %% [markdown]
# Linear regression

# %%
from sklearn.linear_model import LinearRegression

# we limit the training size to avoid memory problems
samples_linreg = 1_000_000

if len(X_train) > samples_linreg:
    sample_index = X_train.sample(n=samples_linreg, random_state=42).index # take a random subset of 1 million rows
    X_train_lin = X_train.loc[sample_index]
    y_train_lin = y_train.loc[sample_index]
    print(f"Linear regression: using a subset of {len(X_train_lin)} rows")
else:
    X_train_lin = X_train
    y_train_lin = y_train
    print(f"Linear regression: using all rows ({len(X_train_lin)})")

# validation data stays the same
X_val_lin = X_val
y_val_lin = y_val

# create the linear regression model
linreg_model = LinearRegression()

# train the model
linreg_model.fit(X_train_lin, y_train_lin)

# Make predictions with log
y_train_pred_lin = linreg_model.predict(X_train_lin)
y_val_pred_lin   = linreg_model.predict(X_val_lin)

# compute rmse to measure prediction error
rmse_train_lin = rmse(y_train_lin, y_train_pred_lin)
rmse_val_lin   = rmse(y_val_lin, y_val_pred_lin)

print("Linear regression (with log) -train rmse :", rmse_train_lin)
print("Linear regression (with log) - validation rmse :", rmse_val_lin)

#compute R² to see how well the model explains the data
r2_train_lin = r2_score(y_train_lin, y_train_pred_lin)
r2_val_lin   = r2_score(y_val_lin, y_val_pred_lin)

print("Linear regression (with log) - train R²  :", r2_train_lin)
print("Linear regression (with log) - val R²    :", r2_val_lin)
# Out:
# Linear regression: using a subset of 1000000 rows
# Linear regression (with log) -train rmse : 1.97719116172666
# Linear regression (with log) - validation rmse : 1.996069421681039
# Linear regression (with log) - train R²  : 0.16089140593446716
# Linear regression (with log) - val R²    : 0.09899738477375053

# %% [markdown]
# Interpretation :
# - train rmse = 1.98 and validation rmse = 2.00: there are still some errors but it's better than the mean model.
#
# - train R² = 0.16: the model explains only 16% of the variation in the data.
# This is low, meaning the model isn't very good.
#
# - validation R² =0.099: the model explains only about 10% of the validation data. It doesn't generalize well.
#
# So, linear regression performs better than the mean model, but it is still not enough for our dataset. The data is complex and has non-linear patterns, so linear regression isn't a good choice of model.

# %% [markdown]
# LightGBM model

# %%
# %pip install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\sulta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# LightGBM model

import lightgbm as lgb

# we take a smaller sample to avoid RAM issues
samples_lgbm = 1_000_000

if len(X_train) > samples_lgbm:
    sample_index_lgbm = X_train.sample(n=samples_lgbm, random_state=42).index
    X_train_lgbm = X_train.loc[sample_index_lgbm]
    y_train_lgbm = y_train.loc[sample_index_lgbm]
    print(f"LightGBM: using a sample of {len(X_train_lgbm)} rows")
else:
    X_train_lgbm = X_train
    y_train_lgbm = y_train
    print(f"LightGBM: using all rows ({len(X_train_lgbm)})")

# validation set
X_val_lgbm = X_val
y_val_lgbm = y_val

# create the lightGBM model
lgbm_model = lgb.LGBMRegressor(
    n_estimators=500,
    learning_rate=0.05,
    num_leaves=64,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1)

# train the model
lgbm_model.fit(X_train_lgbm, y_train_lgbm)

# make predictions (log)
y_train_pred_lgbm = lgbm_model.predict(X_train_lgbm)
y_val_pred_lgbm   = lgbm_model.predict(X_val_lgbm)

# RMSE
rmse_train_lgbm = rmse(y_train_lgbm, y_train_pred_lgbm)
rmse_val_lgbm   = rmse(y_val_lgbm, y_val_pred_lgbm)

print("LightGBM (log) -train rmse :", rmse_train_lgbm)
print("LightGBM (log) - validation rmse :", rmse_val_lgbm)

# compute R²
r2_train_lgbm = r2_score(y_train_lgbm, y_train_pred_lgbm)
r2_val_lgbm   = r2_score(y_val_lgbm, y_val_pred_lgbm)

print("LightGBM (log) -train R² :", r2_train_lgbm)
print("LightGBM (log) - validation R² :", r2_val_lgbm)
# Out:
# LightGBM: using a sample of 1000000 rows
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012735 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1504
# [LightGBM] [Info] Number of data points in the train set: 1000000, number of used features: 14
# [LightGBM] [Info] Start training from score 4.138021
# LightGBM (log) -train rmse : 0.9576706117332779
# LightGBM (log) - validation rmse : 1.2711307666698195
# LightGBM (log) -train R² : 0.8031419545164452
# LightGBM (log) - validation R² : 0.6346112013696852

# %% [markdown]
# Interpretation :
# - train rmse = 0.96 :the model makes some errors on the training data, but less than the previous models
# - validation rmse = 1.27 : the error is higher, but still much better than with linear regression and the mean model. This means LightGBM generalizes better.
# - train R² = 0.80 :the model explains about 80% of the variation in the training data. This is good.
# - validation R² = 0.63 : the model explains about 63% of the variation.
#
#
# LightGBM is much better than the previous models. It gives good predictions.It is a good model for this dataset.

# %% [markdown]
# XGBoost model

# %%
# %pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\sulta\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# XGBoost model

import xgboost as xgb

samples_xgb = 1_000_000

if len(X_train) > samples_xgb:
    sample_index_xgb = X_train.sample(n=samples_xgb, random_state=42).index
    X_train_xgb = X_train.loc[sample_index_xgb]
    y_train_xgb = y_train.loc[sample_index_xgb]
    print(f"XGBoost: using a sample of {len(X_train_xgb)} rows")
else:
    X_train_xgb = X_train
    y_train_xgb = y_train
    print(f"XGBoost: using all rows ({len(X_train_xgb)})")

# validation data
X_val_xgb = X_val
y_val_xgb = y_val

# create the XGBoost model
xgb_model = xgb.XGBRegressor(
    n_estimators=300, # the model will create 300 trees
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8, #each tree uses 80% of the training rows
    colsample_bytree=0.8, #each tree uses 80% of the features
    objective="reg:squarederror",
    tree_method="hist",
    random_state=42,
    n_jobs=-1) #make the training faster

# train the model
xgb_model.fit(X_train_xgb, y_train_xgb)

# predictions
y_train_pred_xgb = xgb_model.predict(X_train_xgb)
y_val_pred_xgb   = xgb_model.predict(X_val_xgb)

# rmse
rmse_train_xgb = rmse(y_train_xgb, y_train_pred_xgb)
rmse_val_xgb   = rmse(y_val_xgb, y_val_pred_xgb)

print("XGBoost (log) -train rmse :", rmse_train_xgb)
print("XGBoost (log) - validation rmse :", rmse_val_xgb)

#R²
r2_train_xgb = r2_score(y_train_xgb, y_train_pred_xgb)
r2_val_xgb   = r2_score(y_val_xgb, y_val_pred_xgb)

print("XGBoost (log) - train R² :", r2_train_xgb)
print("XGBoost (log) - validation R² :", r2_val_xgb)
# Out:
# XGBoost: using a sample of 1000000 rows
# XGBoost (log) -train rmse : 1.2103281
# XGBoost (log) - validation rmse : 1.3687217
# XGBoost (log) - train R² : 0.6855677366256714
# XGBoost (log) - validation R² : 0.5763521194458008

# %% [markdown]
# Interpretation :
#
# - train rmse = 1.21 :the model makes some errors on the training data but performs well
#
# -  validation rmse = 1.37 : the error is a bit higher but still good. The model generalizes well
# -train R² = 0.68 :the model explains about 68% of the training data
# - validation R² = 0.57 : the model explains about 57% of the validation data, which is good.
#
#
# XGBoost works well. It predicts better than the mean model and linear regression, but it is a bit worse than LightGBM

# %% [markdown]
# We choose XGBoost for hyperparameter tuning because it already gives good results (good RMSE and good R²). It's also easier to tune than lightGBM because XGboost has fewer parameters to adjust. Even if lightGBM is a bit better according to our previous results, XGBoost might become better after tuning and become the best model

# %% [markdown]
# Tune hyperparameters

# %% [markdown]
# we tune hyperparameters to make the model perform better. The default settings aren't optimal, so testing different values helps to improve the predictions

# %%
import xgboost as xgb

#set the default parameters
n_estimators_base    = 300 #number of trees
learning_rate_base   = 0.05
max_depth_base       = 6
subsample_base       = 0.8 #use 80% of the rows for each tree
colsample_bytree_base = 0.8  # use 80% of the features for each tree
objective_base       = "reg:squarederror"
tree_method_base     = "hist"
random_state_base    = 42
n_jobs_base          = -1

print("default parameters :")
print("n_estimators     :", n_estimators_base)
print("learning_rate    :", learning_rate_base)
print("max_depth        :", max_depth_base)
print("subsample        :", subsample_base)
print("colsample_bytree :", colsample_bytree_base)
# Out:
# default parameters :
# n_estimators     : 300
# learning_rate    : 0.05
# max_depth        : 6
# subsample        : 0.8
# colsample_bytree : 0.8

# %% [markdown]
# Tuning of n_estimators

# %%
# create a list of values to test
n_estimators_list = [200, 300, 400]

best_n_estimators = None  #to store the best value
best_val_rmse_n   = float("inf") #start with a big rmse

for n_estimators in n_estimators_list:
    print("\ntest with n_estimators =", n_estimators)

    # create the model
    model = xgb.XGBRegressor(
        n_estimators=n_estimators,
        learning_rate=learning_rate_base,
        max_depth=max_depth_base,
        subsample=subsample_base,
        colsample_bytree=colsample_bytree_base,
        objective=objective_base,
        tree_method=tree_method_base,
        random_state=random_state_base,
        n_jobs=n_jobs_base)

    # train the model
    model.fit(X_train_xgb, y_train_xgb)

    #predictions
    y_train_pred = model.predict(X_train_xgb)
    y_val_pred   = model.predict(X_val_xgb)

    # rmse
    rmse_train = rmse(y_train_xgb, y_train_pred)
    rmse_val   = rmse(y_val_xgb, y_val_pred)

    print("Train rmse :", rmse_train)
    print("Val   rmse :", rmse_val)

    # keep the best value
    if rmse_val < best_val_rmse_n:
        best_val_rmse_n   = rmse_val
        best_n_estimators = n_estimators

print("\nbest n_estimators", best_n_estimators,
      "with validation rmse =", best_val_rmse_n)

# update the base value
n_estimators_base = best_n_estimators
# Out:
# test with n_estimators = 200
# Train rmse : 1.2729566
# Val   rmse : 1.4125082
#
# test with n_estimators = 300
# Train rmse : 1.2103281
# Val   rmse : 1.3687217
#
# test with n_estimators = 400
# Train rmse : 1.1516124
# Val   rmse : 1.3343621
#
# best n_estimators 400 with validation rmse = 1.3343621

# %% [markdown]
# Interpretation :
#
# When n_estimators = 200, the validation rmse is 1.416, which is the worst result
#
# With n_estimators = 300, the validation rmse improves to 1.370.
#
# When n_estimators = 400, the validation rmse becomes 1.330, which is the best score.
# So, it gives the lowest validation error, meaning the model predicts better with this value, n_estimators = 400 is the best choice.

# %% [markdown]
# Tuning of max_depth

# %%
# values to test
max_depth_list = [4, 6, 8]

best_max_depth = None
best_val_rmse_d = float("inf")

for max_depth in max_depth_list:
    print("\nTest with max_depth =", max_depth)

    model = xgb.XGBRegressor(
        n_estimators=n_estimators_base,
        learning_rate=learning_rate_base,
        max_depth=max_depth,
        subsample=subsample_base,
        colsample_bytree=colsample_bytree_base,
        objective=objective_base,
        tree_method=tree_method_base,
        random_state=random_state_base,
        n_jobs=n_jobs_base)

    model.fit(X_train_xgb, y_train_xgb)

    y_train_pred = model.predict(X_train_xgb)
    y_val_pred   = model.predict(X_val_xgb)

    rmse_train = rmse(y_train_xgb, y_train_pred)
    rmse_val   = rmse(y_val_xgb, y_val_pred)

    print("Train rmse :", rmse_train)
    print("val   RMSrmseE :", rmse_val)

    if rmse_val < best_val_rmse_d:
        best_val_rmse_d = rmse_val
        best_max_depth  = max_depth

print("\nbest max_depth =", best_max_depth,
      "with validation rmse =", best_val_rmse_d)

max_depth_base = best_max_depth
# Out:
# Test with max_depth = 4
# Train rmse : 1.3955846
# val   RMSrmseE : 1.5116966
#
# Test with max_depth = 6
# Train rmse : 1.1516124
# val   RMSrmseE : 1.3343621
#
# Test with max_depth = 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 21
#       8 print("\nTest with max_depth =", max_depth)
#      10 model = xgb.XGBRegressor(
#      11     n_estimators=n_estimators_base,
#      12     learning_rate=learning_rate_base,
#    (...)     18     random_state=random_state_base,
#      19     n_jobs=n_jobs_base)
# ---> 21 model.fit(X_train_xgb, y_train_xgb)
#      23 y_train_pred = model.predict(X_train_xgb)
#      24 y_val_pred   = model.predict(X_val_xgb)
#
# ...

# %% [markdown]
# Interpretation :
#
# with max_depth = 4 :the rmse is high with train and validation.
#
# When max_depth = 6 : the results are better
#
# with max_depth = 8 :the model gives the lowest validation rmse  (1.23)
#
# So, max_depth = 8 is the best choice because it gives the smallest validation error.

# %% [markdown]
# Optimized Final XGBoost Model

# %%
#XGBoost model with tuned hyperparameters
xgb_best_model = xgb.XGBRegressor(
    n_estimators=n_estimators_base,
    learning_rate=learning_rate_base,
    max_depth=max_depth_base,
    subsample=subsample_base,
    colsample_bytree=colsample_bytree_base,
    objective=objective_base,
    tree_method=tree_method_base,
    random_state=random_state_base,
    n_jobs=n_jobs_base)

xgb_best_model.fit(X_train_xgb, y_train_xgb)

# predictions
y_train_pred_best = xgb_best_model.predict(X_train_xgb)
y_val_pred_best   = xgb_best_model.predict(X_val_xgb)

rmse_train_best = rmse(y_train_xgb, y_train_pred_best)
rmse_val_best   = rmse(y_val_xgb, y_val_pred_best)

print("\nXGBoost optimized - train rmse :", rmse_train_best)
print("XGBoost optimized - validation rmse :", rmse_val_best)

# R²
r2_train_best = r2_score(y_train_xgb, y_train_pred_best)
r2_val_best   = r2_score(y_val_xgb,   y_val_pred_best)

print("XGBoost optimized  - train R² :", r2_train_best)
print("XGBoost optimized - val   R² :", r2_val_best)
# Out:
# XGBoost optimized - train rmse : 0.9176129
# XGBoost optimized - validation rmse : 1.2331133
# XGBoost optimized  - train R² : 0.8192659616470337
# XGBoost optimized - val   R² : 0.6561408042907715

# %% [markdown]
# Interpretation:
#
# - train RMSE = 0.92 : the model makes small errors on the training data
#
# - validation RMSE = 1.23 :the model also performs well on new data
# - train R² = 0.82 ,the model explains 82% of the training data
# - and validation R² = 0.65:the model explains 65% of the validation data
#
# So, the optimized XGBoost model gives better results than the previous models.

# %%
import pandas as pd

results = pd.DataFrame({
    "Model": [
        "Mean model",
        "Linear regression",
        "LightGBM",
        "XGBoost",
        "XGBoost optimized"
    ],
    "rmse train": [
        2.1603806,
        1.9771911528,
        0.9576706117,
        1.212765,
        0.92134833
    ],
    "rmse validation": [
        2.1032665,
        1.996069,
        1.27113076,
        1.3705549,
        1.2308334
    ],
    "R² train": [
        0.0,
        0.160894,
        0.803141,
        0.684300,
        0.817791
    ],
    "R² validation": [
        -0.0003762245,
        0.098997,
        0.634611,
        0.575216,
        0.657411
    ]
})

results
# Out:
#                Model  rmse train  rmse validation  R² train  R² validation
# 0         Mean model    2.160381         2.103267  0.000000      -0.000376
# 1  Linear regression    1.977191         1.996069  0.160894       0.098997
# 2           LightGBM    0.957671         1.271131  0.803141       0.634611
# 3            XGBoost    1.212765         1.370555  0.684300       0.575216
# 4  XGBoost optimized    0.921348         1.230833  0.817791       0.657411

# %%
results.plot(x="Model", y=["rmse train", "rmse validation"], kind="bar", figsize=(10,6))
# Out:
# <Axes: xlabel='Model'>

# %% [markdown]
# This graph compares the train and validation rmse for all the models.
# We can see that:
# - the mean model and the linear regression have very high rmse on both train and validation, so they don't perform well
# - lightGBM and XGBoost have lower rmse, meaning they predict better.
# - the optimized XGBoost model has the lowest validation rmse among all models.
# This means it's the most accurate and it generalizes the best.

# %%
results.plot(
    x="Model",
    y=["R² train", "R² validation"],
    kind="bar",
    figsize=(10,6),
    title="R² train and validation for each model"
)
# Out:
# <Axes: title={'center': 'R² train and validation for each model'}, xlabel='Model'>

# %% [markdown]
# With this graph, we see how much each model explains the variation in the energy consumption.
#
# The mean model and linear regression have very low R², meaning they explain almost nothing in the data.
# LightGBM and XGBoost have much higher R² scores, so they perform better.
# The optimized XGBoost model has the highest R² on both train and validation, which means it is the most accurate.
#
# So, the LightGBM and XGBoost perform better, and tuning the parameters improves the performance even more (XGBoost optimized)

# %% [markdown]
# # 8. Results and Conclusion

# %% [markdown]
# In this project, we studied energy consumption by combining building characteristics, weather information, and time features. After cleaning the data, fixing missing values, creating new variables, and merging all datasets, we trained and compared several models.
#
# Here's the results :
#
# The mean model and linear regression don't perform well because of the complexity of the data
#
# LightGBM and XGBoost performed much better because they can learn complex patterns.
#
# After hyperparameter tuning, the optimized XGBoost model became the best model, with the lowest validation rmse and the highest R². This means it predicts energy consumption more accurately and generalizes better than all other models.
#
# To conclude, this study shows that data preprocessing, feature engineering, and the use of machine learning models are important when we work with large and complex datasets. This work helps to improve energy consumption prediction, which can support better energy management and reduced environmental impact.
